# %%
#OKOYE CHUKWUJINDUM MICHEAL 23/0910 IT GROUP C

# %%
n = 13 
print  (n)
# Out:
# 13

# %%
Score = 98.9
print (Score)
# Out:
# 98.9

# %%
S = 23+24
print (S)
# Out:
# 47

# %%
StudentName ="Okoye chukwujindum"
print (StudentName)
# Out:
# Okoye chukwujindum

# %%
question = "Are you okay?"
yes = True
no = False
print(question)
print(yes)
# Out:
# Are you okay?
# True

# %%
#Lists, sets, tuples and dictionary!

# %%
age = [26, 45, 78, 66, 89, 87]
print(age)
# Out:
# [26, 45, 78, 66, 89, 87]

# %%
age = { 33, 76, 21, 77, 54, 77}
print(age)
# Out:
# {33, 21, 54, 76, 77}

# %%
number = (34, 66, 21, 55, 12, 45)
print(number)
# Out:
# (34, 66, 21, 55, 12, 45)

# %%
studentInfo = {
    "name": "Okoye",
    "age ": 23,
    "is_studentInfo": True
}

print(studentInfo.values())
# Out:
# dict_values(['Okoye', 23, True])
